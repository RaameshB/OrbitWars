# %% [markdown]
# # TPUv6E1

# %%
# Install Specific Dependencies for QDax & JAX
# Using jax[cuda12] as standard for modern NVIDIA GPUs. Change to cuda13 if your instance explicitly requires it.
# !apt remove python3-blinker
# !pip install -U "jax[tpu]" flax optax orbax-checkpoint
# !pip install qdax==0.5.0 brax==0.14.2
# !pip install python-dotenv awscli
# !pip install jaxtyping
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'python3-blinker' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   distro-info-data gir1.2-packagekitglib-1.0 libappstream4 libdw1
#   libgstreamer1.0-0 libpackagekit-glib2-18 libpolkit-agent-1-0
#   libpolkit-gobject-1-0 libstemmer0d libxmlb2 libyaml-0-2 lsb-release
#   packagekit pkexec policykit-1 polkitd python-apt-common python3-apt
#   python3-cffi-backend python3-cryptography python3-dbus python3-distro
#   python3-gi python3-httplib2 python3-jeepney python3-jwt python3-keyring
#   python3-lazr.uri python3-pkg-resources python3-pyparsing
#   python3-secretstorage python3-six python3-wadllib
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
# ...

# %%
# Make sure you have uploaded the following files to the Colab content directory:
# 1. train.py
# 2. networks.py
# 3. orbit_wars_jax.py
# 4. .env (containing your Cloudflare R2 credentials)

import os
required_files = ['train_tpu.py', 'networks.py', 'orbit_wars_jax.py', '.env', 'nnx_pgame.py']
missing = [f for f in required_files if not os.path.exists(f)]
assert not missing, f'WARNING: Missing files: {missing}'
print('All files are present!')
# Out:
# All files are present!

# %%
# !python train_tpu.py
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:88: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# Initializing RL Pipeline...
# Started R2 Sync Thread. Syncing /tmp/checkpoints_v3 to s3://orbit-wars-checkpoints every 300s.
# Initializing NNX Architecture...
# Computing CVT Centroids...
# Configuring NNXPgameEmitter...
# Initializing Repertoire...
# Pulling latest checkpoints from R2 for Auto-Resume...
# Starting MAP-Elites Evolutionary Loop from scratch!
# [0000] Time: 78.48s | Max Fitness: 5753.00 | Repertoire Coverage: 0.4%
#   -> Checkpoint saved to /tmp/checkpoints_v3/qdax_rep_0
# [0001] Time: 29.60s | Max Fitness: 5812.00 | Repertoire Coverage: 0.5%
# ...

# %% [markdown]
# # A100

# %%
# Install Specific Dependencies for QDax & JAX
# Using jax[cuda12] as standard for modern NVIDIA GPUs. Change to cuda13 if your instance explicitly requires it.
# !pip uninstall -y jaxlib jax-cuda12-plugin jax-cuda12-pjrt
# !pip install -U "jax[cuda13]" flax optax orbax-checkpoint
# !pip install qdax==0.5.0 brax==0.14.2
# !pip install python-dotenv awscli
# !pip install jaxtyping

# %%
# Make sure you have uploaded the following files to the Colab content directory:
# 1. train.py
# 2. networks.py
# 3. orbit_wars_jax.py
# 4. .env (containing your Cloudflare R2 credentials)

import os
required_files = ['train.py', 'networks.py', 'orbit_wars_jax.py', '.env', 'nnx_pgame.py']
missing = [f for f in required_files if not os.path.exists(f)]
assert not missing, f'WARNING: Missing files: {missing}'
print('All files are present!')

# %%
# Launch the training script!
# !python train.py --hardware cpu
# Out:
# Initializing RL Pipeline...
# Started R2 Sync Thread. Syncing /tmp/checkpoints_v3 to s3://orbit-wars-checkpoints-v2 every 300s.
# Initializing NNX Architecture...
# Computing CVT Centroids...
# Configuring NNXPgameEmitter...
# Initializing Repertoire...
# Pulling latest checkpoints from R2 for Auto-Resume...
# Starting MAP-Elites Evolutionary Loop from scratch!
# [0000] Time: 123.19s | Max Fitness: 11982.00 | Repertoire Coverage: 0.5%
#   -> GPU VRAM Usage: 38918 MB / 40960 MB (95.0%)
# [20:33:13] R2 Sync Failed: fatal error: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
#   -> Checkpoint saved to /tmp/checkpoints_v3/qdax_rep_0
# [0001] Time: 22.13s | Max Fitness: 11982.00 | Repertoire Coverage: 0.7%
#   -> GPU VRAM Usage: 38930 MB / 40960 MB (95.0%)
# [0002] Time: 21.81s | Max Fitness: 11982.00 | Repertoire Coverage: 1.0%
#   -> GPU VRAM Usage: 38930 MB / 40960 MB (95.0%)
# ...

# %% [markdown]
# # RTX Pro 6000 Blackwell

# %%
# Install Specific Dependencies for QDax & JAX
# Using jax[cuda12] as standard for modern NVIDIA GPUs. Change to cuda13 if your instance explicitly requires it.
# !pip uninstall -y jaxlib jax-cuda12-plugin jax-cuda12-pjrt
# !pip install -U "jax[cuda13]" flax optax orbax-checkpoint
# !pip install qdax==0.5.0 brax==0.14.2
# !pip install python-dotenv awscli
# !pip install jaxtyping
# Out:
# Found existing installation: jaxlib 0.7.2
# Uninstalling jaxlib-0.7.2:
#   Successfully uninstalled jaxlib-0.7.2
# Found existing installation: jax-cuda12-plugin 0.7.2
# Uninstalling jax-cuda12-plugin-0.7.2:
#   Successfully uninstalled jax-cuda12-plugin-0.7.2
# Found existing installation: jax-cuda12-pjrt 0.7.2
# Uninstalling jax-cuda12-pjrt-0.7.2:
#   Successfully uninstalled jax-cuda12-pjrt-0.7.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.1/525.1 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 153.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 99.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.6/119.6 MB 24.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 29.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 MB 7.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# Make sure you have uploaded the following files to the Colab content directory:
# 1. train.py
# 2. networks.py
# 3. orbit_wars_jax.py
# 4. .env (containing your Cloudflare R2 credentials)

import os
required_files = ['train.py', 'networks.py', 'orbit_wars_jax.py', '.env', 'nnx_pgame.py']
missing = [f for f in required_files if not os.path.exists(f)]
assert not missing, f'WARNING: Missing files: {missing}'
print('All files are present!')
# Out:
# All files are present!

# %%
# Launch the training script!
# !python train.py --hardware cpu
# Out:
# Initializing RL Pipeline...
# Started R2 Sync Thread. Syncing /tmp/checkpoints_v3 to s3://orbit-wars-checkpoints every 300s.
# Initializing NNX Architecture...
# Computing CVT Centroids...
# Configuring NNXPgameEmitter...
# Initializing Repertoire...
# Pulling latest checkpoints from R2 for Auto-Resume...
# Starting MAP-Elites Evolutionary Loop from scratch!
# [0000] Time: 57.45s | Max Fitness: 4701.00 | Repertoire Coverage: 0.5%
#   -> GPU VRAM Usage: 93077 MB / 97887 MB (95.1%)
#   -> Checkpoint saved to /tmp/checkpoints_v3/qdax_rep_0
# [0001] Time: 18.07s | Max Fitness: 9759.00 | Repertoire Coverage: 0.7%
#   -> GPU VRAM Usage: 93087 MB / 97887 MB (95.1%)
# [0002] Time: 18.08s | Max Fitness: 9759.00 | Repertoire Coverage: 1.1%
#   -> GPU VRAM Usage: 93087 MB / 97887 MB (95.1%)
# [0003] Time: 18.05s | Max Fitness: 9759.00 | Repertoire Coverage: 1.5%
#   -> GPU VRAM Usage: 93087 MB / 97887 MB (95.1%)
# [0004] Time: 18.03s | Max Fitness: 9759.00 | Repertoire Coverage: 1.8%
# ...
